# %%
import pandas as pd
import numpy as np

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
# Display the first 10 rows of ‘chipo’ using the head() function.
chipo.head(10)
# Out:
#    order_id  quantity                              item_name
# 0         1         1           Chips and Fresh Tomato Salsa  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Determine the total number of entries (rows) in ‘chipo’ using shape or info()
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Use shape or columns to find the total number of columns in ‘chipo’.
len(chipo.columns)
# Out:
# 5

# %%
chipo.shape[1]
# Out:
# 5

# %%
# Use columns to print all the column names
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Utilize index to understand how the DataFrame is indexed.
df = pd.DataFrame(chipo)
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Use the value_counts() method on the ‘item_name’ column to find the most ordered item.
most_ordered_item = df['item_name'].value_counts().idxmax()
most_ordered_item
# Out:
# 'Chicken Bowl'

# %%
# Find the total number of items ordered by summing the ‘quantity’ column.
total_ordered = df['quantity'].sum()
total_ordered
# Out:
# 4972

# %%
# Use value_counts() on ‘choice_description’ to find the most ordered item from this column.
most_ordered_item2 = df['choice_description'].value_counts().idxmax()
most_ordered_item2
# Out:
# '[Diet Coke]'

# %%
# Convert ‘item_price’ to a float datatype using apply() and lambda.
# df['item_price'] = df['item_price'].apply(lambda x: float(x))
chipo['item_price'] = chipo['item_price'].apply(lambda c: float(c[1:]))
chipo['item_price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 3
#       1 # Convert ‘item_price’ to a float datatype using apply() and lambda.
#       2 # df['item_price'] = df['item_price'].apply(lambda x: float(x))
# ----> 3 chipo['item_price'] = chipo['item_price'].apply(lambda c: float(c[1:]))
#       4 chipo['item_price']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
#    (...)
#    4624     dtype: float64
#    4625     """
# -> 4626     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
# Calculate the total revenue for the dataset by summing the ‘item_price’ column.
total_revenue = df['item_price'].sum()
# Out:
# 34500.16

# %%
# Find the total number of orders by using the nunique() function on the ‘order_id’ column.
total_orders = df['order_id'].nunique()
total_orders
# Out:
# 1834

# %%
# Compute the average order value by dividing the total revenue by the number of orders.
average_order = total_revenue / total_orders
average_order
# Out:
# 18.811428571428575

# %%
# Determine the total number of unique items sold using the nunique() function on the ‘item_name’ column.
total_num_unique_sold = df['item_name'].nunique()
total_num_unique_sold
# Out:
# 50

# %% [markdown]
# ### EXERCISE 2: Filtering & Sorting (Chipo)

# %%
# Using conditional selection, find the count of products that cost more than $10. Note: the price is listed in the ‘item_price’ column.
count_high_price = df[df['item_price'] > 10]['item_name'].count()
count_high_price
# Out:
# 1130

# %% [markdown]
# ### EXERCISE 3: Grouping

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# Use the groupby() function to find the mean age per occupation.
df = pd.DataFrame(users)
mean_age_per_occupation = df.groupby('occupation')['age'].mean()
mean_age_per_occupation
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Exercise 4 Merge

# %%
# Define the raw data for each DataFrame
data1 = {'Name': ['Alice', 'Bob', 'Charlie'],
         'Age': [25, 30, 28],
         'City': ['New York', 'Los Angeles', 'Chicago']}

data2 = {'Name': ['David', 'Eve', 'Frank'],
         'Occupation': ['Engineer', 'Teacher', 'Doctor'],
         'Salary': [75000, 60000, 90000]}

data3 = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
         'Hobby': ['Photography', 'Hiking', 'Painting', 'Cooking', 'Reading', 'Cycling']}

# %%
# Create DataFrames
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
data3 = pd.DataFrame(data3)

# %%
# Merge data1 and data2 along rows using concat() and assign to all_data
all_data = pd.concat([data1, data2], axis=0)

# Merge data1 and data2 along columns using concat() and assign to all_data_col
all_data_col = pd.concat([data1, data2], axis=1)

# %%
# Print the merged DataFrames
all_data
# Out:
#       Name   Age         City Occupation   Salary
# 0    Alice  25.0     New York        NaN      NaN
# 1      Bob  30.0  Los Angeles        NaN      NaN
# 2  Charlie  28.0      Chicago        NaN      NaN
# 0    David   NaN          NaN   Engineer  75000.0
# 1      Eve   NaN          NaN    Teacher  60000.0
# 2    Frank   NaN          NaN     Doctor  90000.0

# %%
all_data_col
# Out:
#       Name  Age         City   Name Occupation  Salary
# 0    Alice   25     New York  David   Engineer   75000
# 1      Bob   30  Los Angeles    Eve    Teacher   60000
# 2  Charlie   28      Chicago  Frank     Doctor   90000

# %% [markdown]
# ### Exercise 5: Deleting (Iris)

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', sep=',')

# %%
df = pd.DataFrame(iris)

# %%
# Assign column names to the DataFrame
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris.columns = column_names
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
missing_values = iris.isnull().sum()
missing_values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ### Exercise 6: Creating Series & Data Frames Pokemon

# %%
data = {
    'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
    'hp': [45, 39, 44, 45],
    'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
    'pokedex': ['yes', 'no', 'yes', 'no'],
    'type': ['grass', 'fire', 'water', 'bug']
}

pokemon = pd.DataFrame(data)
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %%
# Rearrange the columns in the order: ‘name’, ‘type’, ‘hp’, ‘evolution’, ‘pokedex’ using simple DataFrame indexing.
pokemon = pokemon[['name', 'type', 'hp', 'evolution', 'pokedex']]
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### Exercise 7: Descriptive Statistics

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name
# 0         1         1           Chips and Fresh Tomato Salsa  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
columns_to_drop = ['order_id', 'quantity']
chipo = chipo.drop(columns=columns_to_drop)
chipo
# Out:
#                                   item_name
# 0              Chips and Fresh Tomato Salsa  \
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4617                          Steak Burrito
# 4618                          Steak Burrito
# 4619                     Chicken Salad Bowl
# 4620                     Chicken Salad Bowl
# 4621                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...

# %% [markdown]
# ### Exercise 8 (Investor Data)

# %%
investor_data = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')

# %%
investor_data
# Out:
#           Date  Total Equity  Domestic Equity  World Equity  Hybrid
# 0   2012-12-05         -7426            -6060         -1367     -74  \
# 1   2012-12-12         -8783            -7520         -1263     123
# 2   2012-12-19         -5496            -5470           -26     -73
# 3   2012-12-26         -4451            -4076          -375     550
# 4   2013-01-02        -11156            -9622         -1533    -158
# 5   2013-01-09         14817             7995          6821    2888
# 6   2014-04-02          3155              938          2217     265
# 7   2014-04-09          5761             2080          3681    1482
# 8   2014-04-16          2286              634          1652    1186
# 9   2014-04-23          3530             1392          2138    1239
# 10  2014-04-30         -3890            -3996           106     759
# 11  2014-05-07           632            -2006          2639    -340
# 12  2014-05-14         -1079            -2321          1242    1188
# ...

# %%
investor_data.shape[1]
# Out:
# 9
